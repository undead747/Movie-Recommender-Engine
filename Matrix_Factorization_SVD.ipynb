# %% [markdown]
# ## Library

# %%
import pandas as pd
import numpy as np
import pickle
import operator


from collections import Counter
from surprise.model_selection import cross_validate
from surprise import KNNBasic
from surprise import Reader, SVD, Dataset 
from scipy import sparse
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Loading Data

# %%
smd = pd.read_csv('../the-movies-dataset/movies_metadata_equal_ratings.csv')
ratings = pd.read_csv('../the-movies-dataset/ratings_equal_movies_metadata.csv')
train = pd.read_csv('../the-movies-dataset/ratings_train.csv')
test = pd.read_csv('../the-movies-dataset/ratings_test.csv')

# %%
smd.shape
# Out:
# (9025, 26)

# %%
N = smd.shape[0]

# %%
ratings
# Out:
#        userId      id  rating  movieId   timestamp  movieIndex
# 0           0   152.0     2.5     1371  1260759135        1107
# 1           0  9909.0     2.5       31  1260759144          30
# 2           0   847.0     2.0     2193  1260759198        1739
# 3           0  9426.0     2.5     2455  1260759113        1958
# 4           0  6114.0     3.5     1339  1260759125        1079
# ...       ...     ...     ...      ...         ...         ...
# 99805     670   786.0     2.0     3897  1063503718        3108
# 99806     670  7443.0     4.0     3751  1065111939        2995
# 99807     670  1891.0     5.0     1196  1064890635         949
# 99808     670   279.0     4.0     1225  1065149143         977
# 99809     670  5503.0     4.0      457  1065149159         406
#
# [99810 rows x 6 columns]

# %% [markdown]
# ## Collaborative Filter Using Suprise Framework

# %%
#sim_options = {'name': 'cosine',
#               'user_based': True  # compute  similarities between items
#               }
#algo = KNNBasic(sim_options=sim_options)

# %%
reader = Reader()
algo = SVD()

# %%
train_subject = Dataset.load_from_df(train[['userId', 'movieIndex', 'rating']], reader)
cross_validate(algo, train_subject, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9112  0.9043  0.9068  0.9015  0.8981  0.9044  0.0045
# MAE (testset)     0.7021  0.6986  0.6965  0.6970  0.6909  0.6970  0.0036
# Fit time          2.93    2.94    3.45    3.43    2.91    3.13    0.25
# Test time         0.13    0.09    0.14    0.12    0.13    0.12    0.02
# {'test_rmse': array([0.9112441 , 0.90426223, 0.90678496, 0.90148623, 0.89809809]),
#  'test_mae': array([0.7020992 , 0.6986164 , 0.69649548, 0.69697837, 0.69094787]),
#  'fit_time': (2.9344067573547363,
#   2.9362075328826904,
#   3.4508309364318848,
#   3.43106746673584,
#   2.909374713897705),
#  'test_time': (0.12965822219848633,
#   0.08743739128112793,
#   0.1382007598876953,
#   0.11729931831359863,
#   0.12637591361999512)}

# %%
train
# Out:
#        userId       id  rating  movieId   timestamp  movieIndex
# 0           0  36819.0     1.0     2968  1260759200        2375
# 1           0   9426.0     2.5     2455  1260759113        1958
# 2           0    152.0     2.5     1371  1260759135        1107
# 3           0   1598.0     2.0     1343  1260759131        1083
# 4           0    665.0     2.0     1287  1260759187        1037
# ...       ...      ...     ...      ...         ...         ...
# 79843     670    161.0     4.5     4963  1065111855        3838
# 79844     670   9377.0     4.0     2918  1065149106        2335
# 79845     670    134.0     4.0     4027  1063500993        3223
# 79846     670    165.0     3.5     2011  1063500873        1569
# 79847     670    531.0     5.0     1148  1064891021         912
#
# [79848 rows x 6 columns]

# %%
trainSet = train_subject.build_full_trainset()
algo.fit(trainSet)

# %%
#testSet = trainSet.build_anti_testset()
#predictions = algo.test(testSet)

# %%
#predict_rating_result = []
#for index, row in test.iterrows():
#    predict_rating_result.append(algo.predict(row.userId, row.movieIndex, 3).est)

# %%
predict_rating_result = {}
for index, row in test.iterrows():
    predict_rating_result[row.userId,row.movieIndex] = algo.predict(row.userId, row.movieIndex, 3).est

# %%
len(predict_rating_result)
# Out:
# 19962

# %%
test['pred'] = predict_rating_result.values()    
test
# Out:
#        userId       id  rating  movieId   timestamp  movieIndex      pred
# 0           0   9909.0     2.5       31  1260759144          30  2.554658
# 1           0    847.0     2.0     2193  1260759198        1739  2.646721
# 2           0     97.0     4.0     2105  1260759139        1661  2.657589
# 3           0  11216.0     4.0     1172  1260759205         927  3.351501
# 4           0   1103.0     2.0     1129  1260759185         903  2.599211
# ...       ...      ...     ...      ...         ...         ...       ...
# 19957     670  11310.0     2.5      432  1063503739         381  2.755469
# 19958     670    712.0     3.0      357  1063503998         322  3.720541
# 19959     670    630.0     4.0      919  1065149458         737  3.960282
# 19960     670    687.0     4.0       36  1065149314          34  3.937466
# 19961     670    530.0     3.0     1223  1064891236         975  4.118869
#
# [19962 rows x 7 columns]

# %%
test.shape
# Out:
# (19962, 7)

# %%
se = 0
for index, row in test.iterrows():
    e = row.rating - row.pred
    se += e*e
np.sqrt(se/test.shape[0])
# Out:
# 0.8965533636633798

# %% [markdown]
# ## Predict Movie Have Not Rated Yet

# %%
train_matrix = train[['userId','movieIndex']].values

# %%
def pred_movies_not_in_train(rate_matrix):
    users = rate_matrix[:,0]
    result = {}
    n_users = int(np.max(rate_matrix[:, 0])) + 1
    for i in range(n_users):
        result[i] = []
        ids = np.where(users == i)[0].astype(np.int32)
        item_ids = rate_matrix[ids,1]
        for j in range(N):
            if j not in item_ids: result[i].append(j)
    
    return result

# %%
result = pred_movies_not_in_train(train_matrix)

# %%
len(result[0]),len(result)
# Out:
# (9010, 671)

# %%
predict_rating_result = {}
for user in result:
    for j in result[user]:
        predict_rating_result[user,j] = algo.predict(user, j, 3).est

# %%
user0 = {}
for i in predict_rating_result:
    if i[0] == 0: user0[i[1]] = predict_rating_result[i] 
len(user0)
# Out:
# 9010

# %%
def collaborative_fillter_recommender(userId,predict_rating_result):
    result = {}
    list_movie = []
    for i in predict_rating_result:
        if i[0] == userId:
            result[i[1]] = predict_rating_result[i]
    result = sorted(result.items(), key=operator.itemgetter(1),reverse=True)
    for i in result:
        list_movie.append(i[0])
    return list_movie

# %%
result = collaborative_fillter_recommender(0,predict_rating_result)

# %%
smd.iloc[result]
# Out:
#       adult                              belongs_to_collection     budget  \
# 743   False                                                NaN    1400000
# 4219  False                                                NaN   15000000
# 1327  False                                                NaN   12000000
# 4974  False                                                NaN   31000000
# 3412  False  {'id': 2150, 'name': 'Shrek Collection', 'post...   60000000
# ...     ...                                                ...        ...
# 160   False  {'id': 286162, 'name': 'Power Rangers Collecti...   15000000
# 2157  False                                                NaN  170000000
# 1238  False  {'id': 43064, 'name': 'Speed Collection', 'pos...  160000000
# 1239  False  {'id': 120794, 'name': 'Batman Collection', 'p...  125000000
# 2864  False                                                NaN   44000000
#
#                                                  genres  \
# 743                                           ['Drama']
# 4219    ['Fantasy', 'Adventure', 'Animation', 'Family']
# 1327          ['Crime', 'Drama', 'Romance', 'Thriller']
# 4974        ['Drama', 'Adventure', 'Action', 'History']
# 3412  ['Adventure', 'Animation', 'Comedy', 'Family',...
# ...                                                 ...
# 160   ['Action', 'Adventure', 'Science Fiction', 'Fa...
# 2157  ['Action', 'Adventure', 'Comedy', 'Science Fic...
# 1238                ['Action', 'Adventure', 'Thriller']
# 1239                     ['Action', 'Crime', 'Fantasy']
# 2864               ['Action', 'Science Fiction', 'War']
#
#                                     homepage    id    imdb_id  \
# 743                                      NaN   705  tt0042192
# 4219  http://movies.disney.com/spirited-away   129  tt0245429
# 1327                                     NaN  9281  tt0090329
# 4974                                     NaN    79  tt0299977
# 3412                   http://www.shrek.com/   808  tt0126029
# ...                                      ...   ...        ...
# 160             http://www.powerrangers.com/  9070  tt0113820
# 2157                                     NaN  8487  tt0120891
# 1238                                     NaN  1639  tt0120179
# 1239                                     NaN   415  tt0118688
# 2864                                     NaN  5491  tt0185183
#
#      original_language                           original_title  \
# 743                 en                            All About Eve
# 4219                ja                                 千と千尋の神隠し
# 1327                en                                  Witness
# 4974                zh                                       英雄
# 3412                en                                    Shrek
# ...                ...                                      ...
# 160                 en  Mighty Morphin Power Rangers: The Movie
# 2157                en                           Wild Wild West
# 1238                en                  Speed 2: Cruise Control
# 1239                en                           Batman & Robin
# 2864                en                        Battlefield Earth
#
#                                                overview  ...  runtime  \
# 743   From the moment she glimpses her idol at the s...  ...    138.0
# 4219  A ten year old girl who wanders away from her ...  ...    125.0
# 1327  A sheltered Amish child is the sole witness of...  ...    113.0
# 4974  One man defeated three assassins who sought to...  ...     99.0
# 3412  It ain't easy bein' green -- especially if you...  ...     90.0
# ...                                                 ...  ...      ...
# 160   Power up with six incredible teens who out-man...  ...     92.0
# 2157  Legless Southern inventor Dr. Arliss Loveless ...  ...    106.0
# 1238  Sandra Bullock and Jason Patric star as a youn...  ...    121.0
# 1239  Along with crime-fighting partner Robin and ne...  ...    125.0
# 2864  In the year 3000, man is no match for the Psyc...  ...    118.0
#
#                                        spoken_languages    status  \
# 743   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4219               [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 1327  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...  Released
# 4974               [{'iso_639_1': 'zh', 'name': '普通话'}]  Released
# 3412           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                 ...       ...
# 160            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2157           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1238  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 1239           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2864  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                                 tagline  \
# 743              It's all about women... and their men!
# 4219     The tunnel led Chihiro to a mysterious town...
# 1327  A big city cop. A small country boy. They have...
# 4974           One man's strength will unite an empire.
# 3412                The greatest fairy tale never told.
# ...                                                 ...
# 160                                    The Power Is On!
# 2157                             It's a whole new west.
# 1238  As the stakes get higher, the ride gets even f...
# 1239             Strength. Courage. Honor. And loyalty.
# 2864                               Take Back The Planet
#
#                                         title  video  vote_average vote_count  \
# 743                             All About Eve  False           8.0      367.0
# 4219                            Spirited Away  False           8.3     3968.0
# 1327                                  Witness  False           7.0      390.0
# 4974                                     Hero  False           7.3      647.0
# 3412                                    Shrek  False           7.3     4183.0
# ...                                       ...    ...           ...        ...
# 160   Mighty Morphin Power Rangers: The Movie  False           5.2      153.0
# 2157                           Wild Wild West  False           5.1     1042.0
# 1238                  Speed 2: Cruise Control  False           4.1      439.0
# 1239                           Batman & Robin  False           4.2     1447.0
# 2864                        Battlefield Earth  False           3.0      259.0
#
#                                             description  year
# 743   From the moment she glimpses her idol at the s...  1950
# 4219  A ten year old girl who wanders away from her ...  2001
# 1327  A sheltered Amish child is the sole witness of...  1985
# 4974  One man defeated three assassins who sought to...  2002
# 3412  It ain't easy bein' green -- especially if you...  2001
# ...                                                 ...   ...
# 160   Power up with six incredible teens who out-man...  1995
# 2157  Legless Southern inventor Dr. Arliss Loveless ...  1999
# 1238  Sandra Bullock and Jason Patric star as a youn...  1997
# 1239  Along with crime-fighting partner Robin and ne...  1997
# 2864  In the year 3000, man is no match for the Psyc...  2000
#
# [9010 rows x 26 columns]

# %%
f = open('SVD_predict_rating_result.pckl', 'wb')
pickle.dump(predict_rating_result, f)

f.close()
